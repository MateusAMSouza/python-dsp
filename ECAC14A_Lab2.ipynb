# %% [markdown]
# # Segunda Atividade de Processamento Digital de Sinais - ECAC14A #
# ## Mateus Alexandre M. de Souza - 2021004023 ##

# %% [markdown]
# ### Exercício 1 ###

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercício 2 ###

# %%
import control as ct
sys = ct.tf(5.265, (1., 1.455, 5.265))
print(sys)
# Out:
# <TransferFunction>: sys[6]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#         5.265
# ---------------------
# s^2 + 1.455 s + 5.265

# %%
disc_sys = ct.sample_system(sys, 0.01, 'zoh')
print(disc_sys)
# Out:
# <TransferFunction>: sys[6]$sampled
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
# 0.000262 z + 0.0002607
# ----------------------
# z^2 - 1.985 z + 0.9856
#
# dt = 0.01

# %%
res = ct.step_response(disc_sys).plot()
ct.step_info(disc_sys)
# Out:
# {'RiseTime': np.float64(0.5900000000000001),
#  'SettlingTime': np.float64(4.88),
#  'SettlingMin': np.float64(0.8776048829960147),
#  'SettlingMax': np.float64(1.3498414353890273),
#  'Overshoot': np.float64(34.98414353887405),
#  'Undershoot': 0,
#  'Peak': np.float64(1.3498414353890273),
#  'PeakTime': np.float64(1.44),
#  'SteadyStateValue': np.float64(1.0000000000002125)}

# %% [markdown]
# #### Overshoot: 34.98414353887405 % ###
# #### Tempo de acomodação: 4.88 s ####

# %% [markdown]
# ### Exercício 3 ###

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

h = np.array([2, -5, -3, -1, 1])
x = np.array([1, 2, 3, 1, -1, -2])
print(np.convolve(x, h))
# Out:
# [  2  -1  -7 -20 -17  -3  15   8   1  -2]
